# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

alg_name = 'GA'
excel_file = 'sample_data/data - ' + alg_name+'.xlsx'


df = pd.read_excel(excel_file)
'''correlation_matrix = df.corr()
column1 = 'Empty Spaces'
column2 = 'Negative Space'
column3 = 'Interesting Elements'
column4 = 'Significant Jumps'
column5 = 'Linearity'
column6 = 'Leniency'
column7 = 'Avg Enemy Comp'
column8 = 'Density'

values_column1 = df[column1]
values_column2 = df[column2]
values_column3 = df[column3]
values_column4 = df[column4]
values_column5 = df[column5]
values_column6 = df[column6]
values_column7 = df[column7]
values_column8 = df[column8]

numeric_columns = df.select_dtypes(include='number').columns.tolist()

fig, axs = plt.subplots(len(numeric_columns), len(numeric_columns), figsize=(10, 10))

for i, col1 in enumerate(numeric_columns):
    for j, col2 in enumerate(numeric_columns):
        ax = axs[i, j]
        if i == j:
            ax.hist(df[col1], bins=100, color='skyblue')
        else:
            hb = ax.hexbin(df[col2], df[col1], gridsize=15)
            if i == len(numeric_columns) - 1:
                ax.set_xlabel(col2, fontsize=8)
            else:
                ax.set_xlabel('')
            if j == 0:
                ax.set_ylabel(col1, fontsize=8)
            else:
                ax.set_ylabel('')


            ax.tick_params(axis='both', which='major', labelsize=8)


        if j == len(numeric_columns) - 1:
            fig.colorbar(hb, ax=axs[i, j])
        else:
            ax.set_xticks([])  # Eliminar ticks en ejes no necesarios
            ax.set_yticks([])

plt.suptitle('Corner Plot of Variables with Hexbin Plots')
plt.tight_layout()
plt.show()


sns.pairplot(df, kind='scatter')
plt.suptitle('Corner Plot de Variables')
plt.show()'''

'''plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap de Correlación entre todas las columnas')
plt.show()'''
# Out:
# "plt.figure(figsize=(10, 8))\nheatmap = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')\nplt.title('Heatmap de Correlación entre todas las columnas')\nplt.show()"

# %% [markdown]
# # Experiments

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable

col1 = 'Avg Enemy Comp'
col2 = 'Enemy Count'

selected_columns = [
    col1,
    col2
]


df = pd.read_excel(excel_file)
df_selected = df[selected_columns]

numeric_columns = df_selected.select_dtypes(include='number').columns.tolist()


fig = plt.figure(figsize=(8, 6))
spec = gridspec.GridSpec(ncols=2, nrows=1, width_ratios=[5, 1], figure=fig)

ax = fig.add_subplot(spec[0])

hb = ax.hexbin(df_selected[col2], df_selected[col1], gridsize=25)

ax.set_xlabel(col2, fontsize=10)
ax.set_ylabel(col1, fontsize=10)


ax.tick_params(axis='both', which='major', labelsize=8)
ax.set_box_aspect(1)


divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.01)


cbar = plt.colorbar(hb, cax=cax)
cbar.ax.tick_params(labelsize=8)


title = alg_name + ' - ' + col1 + ' vs ' + col2
ax.set_title(titulo, fontsize=14, pad=10)
ax.title.set_position([0.5, 1.05])

plt.tight_layout()
plt.show()
print(title)
# Out:
# GA - Avg Enemy Comp vs Enemy Count

# %% [markdown]
# Diagrama caja bigote

# %%
import pandas as pd
import matplotlib.pyplot as plt

col1 = 'Leniency'
col2 = 'Linearity'
col3 = 'Avg Enemy Comp'
col4 = 'Enemy Count'



selected_columns = [
    col1,
    col2,
    col3,
    col4
]

df_selected = df[selected_columns]


plt.figure(figsize=(6, 6))
sns.boxplot(data=df_selected, width=0.5)


plt.subplots_adjust(wspace=0.5)  s

plt.title(alg_name+' - Difficult metrics', fontsize=14)
plt.ylabel('Values', fontsize=12)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
